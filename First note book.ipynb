# %%
from pandas_datareader import data
df = data.DataReader('AAPL', 'yahoo', '2016/1/1', '2017/1/1')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2015-12-31  26.757500  26.205000  26.752501  26.315001  163649200.0  24.090900
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.111502
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.507280
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.047245
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.074549

# %%
# %matplotlib inline
df.plot(y="Close", color="Green")
# Out:
# <AxesSubplot:xlabel='Date'>
